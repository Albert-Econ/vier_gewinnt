# %%
pip install geopandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
fucku.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 6 entries, Neighborhood_FID to builtup
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 6 non-null      object
# dtypes: object(1)
# memory usage: 268.0+ bytes

# %%
fucku = fucku.set_index("Neighborhood_FID")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13636\1144283745.py in <module>
# ----> 1 fucku = fucku.set_index("Neighborhood_FID")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'set_index'

# %%
fucku = np.asmatrix(fucku)
fucku
# Out:
# matrix([[1],
#         ['06412000'],
#         [0.08446816341553183],
#         [0.0],
#         [0.006072874493927126],
#         [0.07514644351464435]], dtype=object)

# %%
streamlit = gpd.read_file(r"C:\Users\alber\OneDrive\Documents\GitHub\vier_gewinnt\data\streamlit2.gpkg")
streamlit
# Out:
#     Neighborhood_FID  Land_Value  treecover   builtup  shrubland  grassland  \
# 0                  1      6998.5   0.133689  0.729463   0.000000   0.009084
# 1                  2     11756.9   0.249146  0.699297   0.000000   0.008905
# 2                  3      5312.2   0.084468  0.840633   0.000000   0.006073
# 3                  4      9779.6   0.308698  0.658058   0.000000   0.025584
# 4                  5      4236.2   0.478802  0.420782   0.000000   0.095331
# 5                  6      6407.0   0.422453  0.539943   0.000000   0.036121
# 6                  7      5529.3   0.447289  0.524233   0.000000   0.026845
# 7                  8      4334.1   0.196036  0.656307   0.000000   0.049009
# 8                  9      3302.5   0.447060  0.476517   0.000000   0.065875
# 9                 10      3374.7   0.172629  0.649334   0.000000   0.036180
# 10                11      2354.5   0.185395  0.742407   0.000000   0.054471
# ...

# %%
frankfurt = gpd.read_file(r"C:\Users\alber\OneDrive\Documents\GitHub\vier_gewinnt\data\Neighborhoods_Frankfurt_am_Main_2.gpkg")
frankfurt["geometry"]
# Out:
# 0     MULTIPOLYGON (((4226384.447 3000227.322, 42263...
# 1     MULTIPOLYGON (((4227082.463 3001711.312, 42272...
# 2     MULTIPOLYGON (((4225284.051 3000486.630, 42252...
# 3     MULTIPOLYGON (((4225219.883 3002076.156, 42252...
# 4     MULTIPOLYGON (((4225993.384 3003603.082, 42260...
# 5     MULTIPOLYGON (((4227858.464 3003565.575, 42278...
# 6     MULTIPOLYGON (((4227867.212 3001590.060, 42277...
# 7     MULTIPOLYGON (((4231428.842 3001758.583, 42314...
# 8     MULTIPOLYGON (((4228434.896 3001994.720, 42284...
# 9     MULTIPOLYGON (((4222367.116 2998542.440, 42223...
# 10    MULTIPOLYGON (((4225187.773 3000559.672, 42252...
# 11    MULTIPOLYGON (((4223927.377 3003639.158, 42239...
# 12    MULTIPOLYGON (((4229292.753 2999703.690, 42290...
# 13    MULTIPOLYGON (((4228372.722 2999334.966, 42284...
# 14    MULTIPOLYGON (((4219985.848 2996337.431, 42199...
# 15    MULTIPOLYGON (((4229990.364 3000151.595, 42300...
# 16    MULTIPOLYGON (((4225144.928 2998301.578, 42250...
# ...

# %%
max_t = frankfurt["treecover"].max()
max_g = frankfurt["grassland"].max()

x = max_t + max_g 

x
# Out:
# 1.0959695634263038

# %%
outcome_string = "the max value is {}".format(abs_max(1))
print(outcome_string)
# Out:
# the max value is 0.19744116296016606

# %%
frankfurt_final = gpd.read_file(r"C:\Users\alber\OneDrive\Documents\GitHub\vier_gewinnt\data\streamlit.gpkg")
frankfurt_final["geometry"]
# Out:
# 0     MULTIPOLYGON (((4226384.44674 3000227.32158, 4...
# 1     MULTIPOLYGON (((4227082.46278 3001711.31224, 4...
# 2     MULTIPOLYGON (((4225284.05145 3000486.62977, 4...
# 3     MULTIPOLYGON (((4225219.88286 3002076.15554, 4...
# 4     MULTIPOLYGON (((4225993.38385 3003603.08203, 4...
# 5     MULTIPOLYGON (((4227858.46392 3003565.57485, 4...
# 6     MULTIPOLYGON (((4227867.21204 3001590.05997, 4...
# 7     MULTIPOLYGON (((4231428.84153 3001758.58257, 4...
# 8     MULTIPOLYGON (((4228434.89586 3001994.71993, 4...
# 9     MULTIPOLYGON (((4222367.11615 2998542.43979, 4...
# 10    MULTIPOLYGON (((4225187.77261 3000559.67169, 4...
# 11    MULTIPOLYGON (((4223927.37702 3003639.15826, 4...
# 12    MULTIPOLYGON (((4229292.75266 2999703.69013, 4...
# 13    MULTIPOLYGON (((4228372.72181 2999334.96600, 4...
# 14    MULTIPOLYGON (((4219985.84805 2996337.43115, 4...
# 15    MULTIPOLYGON (((4229990.36384 3000151.59513, 4...
# 16    MULTIPOLYGON (((4225144.92751 2998301.57818, 4...
# ...

# %%
frankfurt_final = gpd.read_file(r"C:\Users\alber\OneDrive\Documents\GitHub\vier_gewinnt\data\streamlit2.gpkg")
frankfurt_final
# Out:
#     Neighborhood_FID  Land_Value  treecover   builtup  shrubland  grassland  \
# 0                  1      6998.5   0.133689  0.729463   0.000000   0.009084
# 1                  2     11756.9   0.249146  0.699297   0.000000   0.008905
# 2                  3      5312.2   0.084468  0.840633   0.000000   0.006073
# 3                  4      9779.6   0.308698  0.658058   0.000000   0.025584
# 4                  5      4236.2   0.478802  0.420782   0.000000   0.095331
# 5                  6      6407.0   0.422453  0.539943   0.000000   0.036121
# 6                  7      5529.3   0.447289  0.524233   0.000000   0.026845
# 7                  8      4334.1   0.196036  0.656307   0.000000   0.049009
# 8                  9      3302.5   0.447060  0.476517   0.000000   0.065875
# 9                 10      3374.7   0.172629  0.649334   0.000000   0.036180
# 10                11      2354.5   0.185395  0.742407   0.000000   0.054471
# ...

# %%
frankfurt_git = gpd.read_file("https://github.com/Albert-Econ/vier_gewinnt/blob/main/map/Land_Prices/frankfurt.shp")
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona\ogrext.pyx in fiona.ogrext.gdal_open_vector()
#
# fiona\_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '/vsimem/95ff816294a142b6afa58d7e4275389e' not recognized as a supported file format.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_852\280117311.py in <module>
# ----> 1 frankfurt_git = gpd.read_file("https://github.com/Albert-Econ/vier_gewinnt/blob/main/map/Land_Prices/frankfurt.shp")
#
# ~\anaconda3\lib\site-packages\geopandas\io\file.py in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     257
#     258     if engine == "fiona":
# --> 259         return _read_file_fiona(
# ...

# %%
frankfurt = gpd.read_file(r"C:\Users\alber\OneDrive\Documents\GitHub\vier_gewinnt\map\Land_Prices\frankfurt.shp")
frankfurt
# Out:
#     FID                                           geometry
# 0     0  POLYGON ((4226384.447 3000227.322, 4226339.501...
# 1     1  POLYGON ((4227082.463 3001711.312, 4227227.764...
# 2     2  POLYGON ((4225284.051 3000486.630, 4225282.047...
# 3     3  POLYGON ((4225219.883 3002076.156, 4225299.627...
# 4     4  POLYGON ((4225993.384 3003603.082, 4226010.878...
# 5     5  POLYGON ((4227858.464 3003565.575, 4227818.250...
# 6     6  POLYGON ((4227867.212 3001590.060, 4227794.626...
# 7     7  POLYGON ((4231428.842 3001758.583, 4231404.851...
# 8     8  POLYGON ((4228434.896 3001994.720, 4228433.955...
# 9     9  POLYGON ((4222367.116 2998542.440, 4222365.142...
# 10   10  POLYGON ((4225187.773 3000559.672, 4225282.047...
# 11   11  POLYGON ((4223927.377 3003639.158, 4223952.145...
# 12   12  POLYGON ((4229292.753 2999703.690, 4229001.232...
# 13   13  POLYGON ((4228372.722 2999334.966, 4228419.166...
# 14   14  POLYGON ((4219985.848 2996337.431, 4219999.950...
# ...

# %%
test = gpd.read_file("https://raw.githubusercontent.com/opengeos/leafmap/master/examples/data/cable_geo.geojson")
test
# Out:
#                                                id  \
# 0           taiwan-penghu-kinmen-matsu-no-3-tpkm3
# 1                                unitirreno-cable
# 2                 kochi-lakshadweep-islands-cable
# 3                                          sagres
# 4                              continente-madeira
# ..                                            ...
# 525                                       pgascom
# 526  boracay-palawan-submarine-cable-system-bpscs
# 527                    saudi-arabia-sudan-1-sas-1
# 528                                        falcon
# 529                                     seamewe-3
#
#                                                name    color  \
# 0           Taiwan Penghu Kinmen Matsu No.3 (TPKM3)  #4dbd9a
# 1                                  Unitirreno Cable  #939597
# 2                   Kochi-Lakshadweep Islands Cable  #939597
# 3                                            Sagres  #4ab970
# ...

# %%
pip install streamlit
# Out:
# ...
#   Using cached streamlit-1.22.0-py2.py3-none-any.whl (8.9 MB)
# ...
#   Using cached altair-4.2.2-py3-none-any.whl (813 kB)
# ...
#   Using cached tzlocal-4.3-py3-none-any.whl (20 kB)
# ...
#      -------------------------------------- 904.2/904.2 kB 9.5 MB/s eta 0:00:00
# ...
#   Using cached blinker-1.6.2-py3-none-any.whl (13 kB)
# ...
#   Using cached Pympler-1.0.1-py3-none-any.whl (164 kB)
# ...
#   Using cached rich-13.3.5-py3-none-any.whl (238 kB)
# ...
#   Using cached validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
# ...
#      ---------------------------------------- 1.1/1.1 MB 10.4 MB/s eta 0:00:00
# ...
#   Using cached markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
# ...
#   Using cached pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# ...
#      ------------------------------------- 341.8/341.8 kB 10.4 MB/s eta 0:00:00
# ...

# %%
pip install leafmap
# Out:
# ...
#
#   Using cached leafmap-0.20.0-py2.py3-none-any.whl (1.8 MB)
# ...
#   Using cached geojson-3.0.1-py3-none-any.whl (15 kB)
# ...
#   Using cached scooby-0.7.1-py3-none-any.whl (16 kB)
# ...
#   Using cached pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
# ...
#   Using cached whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
# ...
#   Using cached colour-0.1.5-py2.py3-none-any.whl (23 kB)
# ...
#   Using cached pystac_client-0.6.1-py3-none-any.whl (30 kB)
# ...
#   Using cached gdown-4.7.1-py3-none-any.whl (15 kB)
# ...
#   Using cached ipyleaflet-0.17.2-py3-none-any.whl (3.7 MB)
# ...
#      ---------------------------------------- 1.0/1.0 MB 6.5 MB/s eta 0:00:00
# ...
#   Using cached ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# ...
#   Using cached ipyevents-2.0.1-py2.py3-none-any.whl (130 kB)
# ...
#      ---------------------------------------- 55.4/55.4 kB 2.8 MB/s eta 0:00:00
# ...
#   Using cached bqplot-0.12.39-py2.py3-none-any.whl (1.2 MB)
# ...
#   Using cached folium-0.13.0-py2.py3-none-any.whl (96 kB)
# ...

# %%
pip install streamlit_pandas
# Out:
# ...
#   Using cached streamlit_pandas-0.0.9.tar.gz (3.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached streamlit-1.18.1-py2.py3-none-any.whl (9.6 MB)
# ...
#   Using cached semver-3.0.0-py3-none-any.whl (17 kB)
# ...
#   Created wheel for streamlit_pandas: filename=streamlit_pandas-0.0.9-py3-none-any.whl size=3483 sha256=72f9166dd0b24af9b832488c3020a89c302e1fbb8a58ca01cc9d9ecaf058fc87
#   Stored in directory: c:\users\alber\appdata\local\pip\cache\wheels\97\9e\f8\23a9e756503eff59ed29d093b07e0cc27ace9fc849efeb95cf
# Successfully built streamlit_pandas
# ...
#   Attempting uninstall: streamlit
#     Found existing installation: streamlit 1.22.0
#     Uninstalling streamlit-1.22.0:
#       Successfully uninstalled streamlit-1.22.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import leafmap.foliumap as leafmap
import geopandas as gpd
import streamlit_pandas as sp
import pandas as pd
import numpy as np

# %%
raw_data = gpd.read_file(r"C:\Users\alber\OneDrive\Documents\GitHub\vier_gewinnt\data\streamlit2.gpkg")
gdf = gpd.GeoDataFrame(raw_data)


all_widgets = sp.create_widgets(gdf)
res = sp.filter_df(gdf, all_widgets)
    

m.add_gdf(res, layer_name="frankfurt")

predict_x = pd.DataFrame()
predict_x[list(res.columns)] = res
predict_x = predict_x.drop(["Neighborhood","geometry","Neighborhood_FID","Land_Value"], axis=1)
predict_x = predict_x.astype("float")
predict_x = predict_x.min()
predict_x = np.asmatrix(predict_x)

predict_b = pd.read_csv(r"C:\Users\alber\OneDrive\Documents\GitHub\vier_gewinnt\data\coefs_streamlit2.csv")
predict_b = predict_b.astype("float")
predict_b = np.asmatrix(predict_b)

prediction = predict_x @ predict_b
# Out:
# 2023-04-30 02:54:14.698
# ...
#   command:
#
#     streamlit run C:\Users\alber\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2023-04-30 02:54:14.778 Session state does not function when running a script without `streamlit run`
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\streamlit\runtime\state\session_state.py in __getitem__(self, key)
#     375         state: dict[str, Any] = {}
# --> 376
#     377         # We can't write `for k, v in self.items()` here because doing so will
#
# ~\anaconda3\lib\site-packages\streamlit\runtime\state\session_state.py in _getitem(self, widget_id, user_key)
#     420         This is a shortcut for `iter(self.keys())`
# --> 421         """
#     422         return iter(self._keys())
#
# KeyError:
#
# During handling of the above exception, another exception occurred:
#
# ...
